# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import os
from env import get_db_url
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.preprocessing
import wrangle_zillow
import scipy.stats as stats
alpha = .05
from sklearn.cluster import KMeans

# %% [markdown]
# ### Planning

# %% [markdown]
# ### Acquire

# %%
df = wrangle_zillow.get_zillow_data()
df.head()
# Out:
#    heatingorsystemtypeid  parcelid  storytypeid  typeconstructiontypeid  \
# 0                    NaN  14297519          NaN                     NaN
# 1                    NaN  17052889          NaN                     NaN
# 2                    NaN  14186244          NaN                     NaN
# 3                    2.0  12177905          NaN                     NaN
# 4                    2.0  12095076          NaN                     NaN
#
#    airconditioningtypeid  propertylandusetypeid  architecturalstyletypeid  \
# 0                    NaN                  261.0                       NaN
# 1                    NaN                  261.0                       NaN
# 2                    NaN                  261.0                       NaN
# 3                    NaN                  261.0                       NaN
# 4                    1.0                  261.0                       NaN
#
#         id  basementsqft  bathroomcnt  ...  censustractandblock id  logerror  \
# 0  1727539           NaN          3.5  ...         6.059063e+13  0  0.025595
# 1  1387261           NaN          1.0  ...         6.111001e+13  1  0.055619
# 2    11677           NaN          2.0  ...         6.059022e+13  2  0.005383
# 3  2288172           NaN          3.0  ...         6.037300e+13  3 -0.103410
# 4   781532           NaN          3.0  ...         6.037461e+13  6 -0.001011
#
#    transactiondate  architecturalstyledesc        propertylandusedesc  \
# 0       2017-01-01                    None  Single Family Residential
# 1       2017-01-01                    None  Single Family Residential
# 2       2017-01-01                    None  Single Family Residential
# 3       2017-01-01                    None  Single Family Residential
# 4       2017-01-01                    None  Single Family Residential
#
#    airconditioningdesc  typeconstructiondesc storydesc heatingorsystemdesc
# 0                 None                  None      None                None
# 1                 None                  None      None                None
# 2                 None                  None      None                None
# 3                 None                  None      None             Central
# 4              Central                  None      None             Central
#
# [5 rows x 68 columns]

# %% [markdown]
# ### Prepare

# %%
df = wrangle_zillow.prepare_zillow_data(df)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/09/fk3d1qyj46g4t3qj46nfxzvw0000gn/T/ipykernel_48737/3694283019.py in <module>
# ----> 1 df = wrangle_zillow.prepare_zillow_data(df)
#       2 df.head()
#
# ~/Codeup/codeup-data-science/projects/Zillow_project_logerror/wrangle_zillow.py in prepare_zillow_data(df)
#     121     df = remove_outliers(df,k=1.5)
#     122     df = map_counties(df)
# --> 123     df = remove_columns(df,cols_to_remove)
#     124     df = integers(df)
#     125     return df
#
# ~/Codeup/codeup-data-science/projects/Zillow_project_logerror/wrangle_zillow.py in remove_columns(df, cols_to_remove)
#      61
#      62 def remove_columns(df, cols_to_remove):
# ---> 63     df = df.drop(columns=cols_to_remove)
#      64     return df
#      65
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['parcelid' 'propertylandusetypeid' 'id' 'calculatedbathnbr'\n 'finishedsquarefeet12' 'fullbathcnt' 'propertycountylandusecode'\n 'rawcensustractandblock' 'regionidcounty' 'roomcnt'\n 'structuretaxvaluedollarcnt' 'assessmentyear' 'landtaxvaluedollarcnt'\n 'censustractandblock' 'id'] not found in axis"

# %% [markdown]
# ### Explore

# %% [markdown]
# ### Cluster

# %% [markdown]
# ### Model
